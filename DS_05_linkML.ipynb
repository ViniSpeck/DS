# %% [markdown]
# <a href="https://colab.research.google.com/github/ViniSpeck/DS/blob/main/DS_05_linkML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Detecção de Fraudes em Cartões de Crédito**
#
# Neste projeto, iremos abordar o problema das fraudes em cartões de crédito, uma das principais preocupações das instituições financeiras como bancos e fintechs. Apenas no Brasil, cerca de 12,1 milhões de pessoas já foram vítimas de algum tipo de fraude financeira no último ano contabilizando R$ 1,8 bilhão de prejuízo.
#
# Os bancos usam algoritmos para tentar detectar possíveis fraudes que bloqueiam automaticamente o cartão de crédito quando alguma operação suspeita é detectada. Um outro fator a ser considerado é a quantidade de falsos positivos, ou seja, aquelas vezes em que você tentou fazer uma compra e teve seu cartão bloqueado preventivamente - o que provavelmente gerou estresse e constrangimento.
#
# Dispondo de grandes volumes de dados como base histórica, um algoritmo de machine learning apenas um pouco melhor que aqueles já existem já representa uma economia de milhões de Reais.
#
# Você utilizará o dataset anexado a esta tarefa que contém um conjunto de transações verdadeiras ocorridas em bancos da Europa. Um desafio extra é não saber exatamente o que significa algumas das colunas de dados, que tiveram seus nomes trocados através de um processo chamado "PCA Transformation" para garantir anonimidade dos clientes dos bancos.
#
# Esta é a primeira parte da atividade do processo de criação de um machine learning dentro do contexto de ciência de dados.
#
# Equipe: Vinícius Speck e Eduardo Paterno

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# Importando bibliotecas e o dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from google.colab import drive
# %matplotlib inline

drive.mount('/content/drive')

df=pd.read_csv("/content/drive/MyDrive/Datasets/fraudescartaodecredito.csv")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Visualizando as 15 primeiras entradas do dataset

# %%
df.head(15)
# Out:
#     Time        V1        V2        V3        V4        V5        V6  \
# 0    0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1    0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2    1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3    1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4    2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# 5    2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728
# 6    4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708
# 7    7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118
# 8    7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818
# 9    9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761
# 10  10.0  1.449044 -1.176339  0.913860 -1.375667 -1.971383 -0.629152
# 11  10.0  0.384978  0.616109 -0.874300 -0.094019  2.924584  3.317027
# 12  10.0  1.249999 -1.221637  0.383930 -1.234899 -1.485419 -0.753230
# ...

# %% [markdown]
# Consultando o resumo estatístico do dataset

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %% [markdown]
# Consultando a existência de valores nulos na tabela

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# Plotando um gráfico de barras para verificar o balanceamento do dataset

# %%
df.plot.barh()

# %% [markdown]
# Dividindo o dataframe entre as transações fraudulentas e normais

# %%
df_fraud = df.loc[df['Class']==1]
df_normal = df.loc[df['Class']==0]

# %% [markdown]
# Histograma das variáveis *Time* e *Amount*

# %%
df_normal.Time.hist(bins=3)
plt.title('Time (Normal)')
plt.show()
df_fraud.Time.hist(bins=3)
plt.title('Time (Fraud)')
plt.show()
df_normal.Amount.hist(bins=3)
plt.title('Amount (Normal)')
plt.show()
df_fraud.Amount.hist(bins=3)
plt.title('Amount (Fraud)')
plt.show()

# %% [markdown]
# Criando um boxplot para a variável Amount quando houve fraude

# %%
df_fraud.Amount.plot(kind='box', vert=False, figsize=(15,3))
plt.show()

# %% [markdown]
# Mostrando a matriz de correlação

# %%
df.corr()
# Out:
#             Time            V1            V2            V3            V4  \
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1      0.117396  1.000000e+00  4.135835e-16 -1.227819e-15 -9.215150e-16
# V2     -0.010593  4.135835e-16  1.000000e+00  3.243764e-16 -1.121065e-15
# V3     -0.419618 -1.227819e-15  3.243764e-16  1.000000e+00  4.711293e-16
# V4     -0.105260 -9.215150e-16 -1.121065e-15  4.711293e-16  1.000000e+00
# V5      0.173072  1.812612e-17  5.157519e-16 -6.539009e-17 -1.719944e-15
# V6     -0.063016 -6.506567e-16  2.787346e-16  1.627627e-15 -7.491959e-16
# V7      0.084714 -1.005191e-15  2.055934e-16  4.895305e-16 -4.104503e-16
# V8     -0.036949 -2.433822e-16 -5.377041e-17 -1.268779e-15  5.697192e-16
# V9     -0.008660 -1.513678e-16  1.978488e-17  5.568367e-16  6.923247e-16
# V10     0.030617  7.388135e-17 -3.991394e-16  1.156587e-15  2.232685e-16
# V11    -0.247689  2.125498e-16  1.975426e-16  1.576830e-15  3.459380e-16
# ...
